# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
import os
import collections
import itertools

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %%
from six.moves import urllib

# %%
print(tf.__version__)
# Out:
# 1.11.0

# %%
URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"

# %%
FILENAME = "automobiles.csv"

# %%
def download_data():
    if not os.path.exists(FILENAME):
        filename, _ = urllib.request.urlretrieve(URL,FILENAME)
    print("Found and downloaded file from {}".format(URL))
    print("Downloaded Filename: {}".format(FILENAME))

# %%
download_data()
# Out:
# Found and downloaded file from https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data
# Downloaded Filename: automobiles.csv

# %%
COLUMN_TYPES = collections.OrderedDict([
    ("symboling", int),
    ("normalized-losses", float),
    ("make", str),
    ("fuel-type", str),
    ("aspiration", str),
    ("num-of-doors", str),
    ("body-style", str),
    ("drive-wheels", str),
    ("engine-location", str),
    ("wheel-base", float),
    ("length", float),
    ("width", float),
    ("height", float),
    ("curb-weight", float),
    ("engine-type", str),
    ("num-of-cylinders", str),
    ("engine-size", float),
    ("fuel-system", str),
    ("bore", float),
    ("stroke", float),
    ("compression-ratio", float),
    ("horsepower", float),
    ("peak-rpm", float),
    ("city-mpg", float),
    ("highway-mpg", float),
    ("price", float)
])

# %%
df = pd.read_csv(FILENAME,names=COLUMN_TYPES.keys(),dtype=COLUMN_TYPES,na_values='?')

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base   ...     \
# 0          two  convertible          rwd           front        88.6   ...
# 1          two  convertible          rwd           front        88.6   ...
# 2          two    hatchback          rwd           front        94.5   ...
# 3         four        sedan          fwd           front        99.8   ...
# 4         four        sedan          4wd           front        99.4   ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0        130.0         mpfi  3.47    2.68               9.0      111.0
# 1        130.0         mpfi  3.47    2.68               9.0      111.0
# 2        152.0         mpfi  2.68    3.47               9.0      154.0
# 3        109.0         mpfi  3.19    3.40              10.0      102.0
# 4        136.0         mpfi  3.19    3.40               8.0      115.0
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0     21.0         27.0  13495.0
# 1    5000.0     21.0         27.0  16500.0
# 2    5000.0     19.0         26.0  16500.0
# 3    5500.0     24.0         30.0  13950.0
# 4    5500.0     18.0         22.0  17450.0
#
# [5 rows x 26 columns]

# %%
df.count()
# Out:
# symboling            205
# normalized-losses    164
# make                 205
# fuel-type            205
# aspiration           205
# num-of-doors         203
# body-style           205
# drive-wheels         205
# engine-location      205
# wheel-base           205
# length               205
# width                205
# height               205
# curb-weight          205
# engine-type          205
# num-of-cylinders     205
# engine-size          205
# fuel-system          205
# bore                 201
# stroke               201
# compression-ratio    205
# horsepower           203
# peak-rpm             203
# city-mpg             205
# highway-mpg          205
# price                201
# dtype: int64

# %%
df = df.dropna()

# %%
TRIMMED_CSV_COLUMNS = [
    "make", "fuel-type", "aspiration", "num-of-doors", "body-style",
    "drive-wheels", "curb-weight", "engine-type", "num-of-cylinders", "engine-size",
    "fuel-system", "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"
]

# %%
df = df[TRIMMED_CSV_COLUMNS]

# %%
df.head()
# Out:
#           make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
#
#    curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0       2548.0        dohc             four        130.0        mpfi
# 1       2548.0        dohc             four        130.0        mpfi
# 2       2823.0        ohcv              six        152.0        mpfi
# 3       2337.0         ohc             four        109.0        mpfi
# 4       2824.0         ohc             five        136.0        mpfi
#
#    horsepower  peak-rpm  city-mpg  highway-mpg    price
# 0       111.0    5000.0      21.0         27.0  13495.0
# 1       111.0    5000.0      21.0         27.0  16500.0
# 2       154.0    5000.0      19.0         26.0  16500.0
# 3       102.0    5500.0      24.0         30.0  13950.0
# 4       115.0    5500.0      18.0         22.0  17450.0

# %%
Y_name = "price"

# %%
def get_training_test_prediction_data(df,y):
    #unique shuffle each time
    np.random.seed(None)
    #Split
    x_train = df.sample(frac=0.7,random_state=None)
    x_test = df.drop(x_train.index)
    x_predict = df.sample(frac=0.2,random_state=None)
    #Extract labels
    y_train = x_train.pop(y)
    y_test = x_test.pop(y)
    y_predict = x_predict.pop(y)
    return (x_train,y_train), (x_test,y_test), (x_predict,y_predict)

# %%
(x_train,y_train), (x_test,y_test), (x_predict,y_predict)= get_training_test_prediction_data(df,Y_name)

# %%
PRICE_SCALING_FACTOR = 10000

y_train /= PRICE_SCALING_FACTOR
y_test /= PRICE_SCALING_FACTOR
y_predict /= PRICE_SCALING_FACTOR

# %%
y_train.head()
# Out:
# 70     3.1600
# 12     2.0970
# 158    0.7898
# 50     0.5195
# 167    0.8449
# Name: price, dtype: float64

# %% [markdown]
# ### Categorical Values

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df['fuel-type'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df["aspiration"].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df['num-of-doors'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
df['body-style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df['engine-type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf'], dtype=object)

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df['fuel-system'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
x_train.keys()
# Out:
# Index(['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style',
#        'drive-wheels', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg'],
#       dtype='object')

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 70 to 120
# Data columns (total 15 columns):
# make                138 non-null object
# fuel-type           138 non-null object
# aspiration          138 non-null object
# num-of-doors        138 non-null object
# body-style          138 non-null object
# drive-wheels        138 non-null object
# curb-weight         138 non-null float64
# engine-type         138 non-null object
# num-of-cylinders    138 non-null object
# engine-size         138 non-null float64
# fuel-system         138 non-null object
# horsepower          138 non-null float64
# peak-rpm            138 non-null float64
# city-mpg            138 non-null float64
# highway-mpg         138 non-null float64
# dtypes: float64(6), object(9)
# memory usage: 17.2+ KB

# %%
curb_weight = tf.feature_column.numeric_column("curb-weight")

engine_size = tf.feature_column.numeric_column("engine-size")

horsepower = tf.feature_column.numeric_column("horsepower")

peak_rpm = tf.feature_column.numeric_column("peak-rpm")

city_mpg = tf.feature_column.numeric_column("city-mpg")

highway_mpg = tf.feature_column.numeric_column("highway-mpg")

# %%
body_style = tf.feature_column.categorical_column_with_vocabulary_list(
      key="body-style", vocabulary_list=df['body-style'].unique())

fuel_type = tf.feature_column.categorical_column_with_vocabulary_list(
      key="fuel-type", vocabulary_list=df['fuel-type'].unique())

aspiration = tf.feature_column.categorical_column_with_vocabulary_list(
      key="aspiration", vocabulary_list=df['aspiration'].unique())

num_of_doors = tf.feature_column.categorical_column_with_vocabulary_list(
      key="num-of-doors", vocabulary_list=df['num-of-doors'].unique())

drive_wheels = tf.feature_column.categorical_column_with_vocabulary_list(
      key="drive-wheels", vocabulary_list=df['drive-wheels'].unique())

engine_type = tf.feature_column.categorical_column_with_vocabulary_list(
      key="engine-type", vocabulary_list=df['engine-type'].unique())

num_of_cylinders = tf.feature_column.categorical_column_with_vocabulary_list(
      key="num-of-cylinders", vocabulary_list=df['num-of-cylinders'].unique())

fuel_system = tf.feature_column.categorical_column_with_vocabulary_list(
      key="fuel-system", vocabulary_list=df['fuel-system'].unique())

# %%
make = tf.feature_column.categorical_column_with_hash_bucket(key='make',hash_bucket_size=50)

# %%
feature_columns = [
    curb_weight, engine_size, horsepower, peak_rpm, city_mpg, highway_mpg,

    tf.feature_column.indicator_column(body_style),

    tf.feature_column.embedding_column(fuel_type, dimension=3),

    tf.feature_column.embedding_column(aspiration, dimension=3),
    tf.feature_column.embedding_column(num_of_doors, dimension=3),
    tf.feature_column.embedding_column(drive_wheels, dimension=3),
    tf.feature_column.embedding_column(engine_type, dimension=3),
    tf.feature_column.embedding_column(num_of_cylinders, dimension=3),
    tf.feature_column.embedding_column(fuel_system, dimension=3),

    tf.feature_column.embedding_column(make, dimension=4)    
]

# %%
def input_fn(x_data,y_data,num_epochs,shuffle):
    return tf.estimator.inputs.pandas_input_fn(x_data,y_data,batch_size=64,num_epochs=num_epochs,shuffle=shuffle)

# %%
model = tf.estimator.DNNRegressor(hidden_units=[20,20,20],feature_columns=feature_columns)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Lolly\AppData\Local\Temp\tmpaf205_wz
# INFO:tensorflow:Using config: {'_is_chief': True, '_save_summary_steps': 100, '_eval_distribute': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_task_type': 'worker', '_model_dir': 'C:\\Users\\Lolly\\AppData\\Local\\Temp\\tmpaf205_wz', '_evaluation_master': '', '_task_id': 0, '_experimental_distribute': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_train_distribute': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_global_id_in_cluster': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000010A126ED1D0>, '_service': None, '_num_worker_replicas': 1, '_device_fn': None, '_protocol': None, '_num_ps_replicas': 0, '_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None}

# %%
model.train(input_fn=input_fn(x_train,y_train,num_epochs=None,shuffle=True),steps=10000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Lolly\AppData\Local\Temp\tmpaf205_wz\model.ckpt-130
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 130 into C:\Users\Lolly\AppData\Local\Temp\tmpaf205_wz\model.ckpt.
# INFO:tensorflow:loss = 387.28546, step = 131
# INFO:tensorflow:global_step/sec: 77.565
# INFO:tensorflow:loss = 420.0084, step = 231 (1.292 sec)
# INFO:tensorflow:global_step/sec: 120.874
# INFO:tensorflow:loss = 234.89034, step = 331 (0.838 sec)
# INFO:tensorflow:global_step/sec: 143.031
# INFO:tensorflow:loss = 279.70108, step = 431 (0.687 sec)
# INFO:tensorflow:global_step/sec: 111.098
# INFO:tensorflow:loss = 288.0074, step = 531 (0.909 sec)
# INFO:tensorflow:global_step/sec: 128.793
# INFO:tensorflow:loss = 41.635353, step = 8631 (0.534 sec)
# INFO:tensorflow:global_step/sec: 156.668
# INFO:tensorflow:loss = 39.996365, step = 8731 (0.640 sec)
# INFO:tensorflow:global_step/sec: 179.049
# INFO:tensorflow:loss = 57.44725, step = 8831 (0.556 sec)
# INFO:tensorflow:global_step/sec: 158.401
# INFO:tensorflow:loss = 44.490738, step = 8931 (0.634 sec)
# INFO:tensorflow:global_step/sec: 182.637
# INFO:tensorflow:loss = 42.0784, step = 9031 (0.547 sec)
# INFO:tensorflow:global_step/sec: 158.148
# INFO:tensorflow:loss = 35.36196, step = 9131 (0.633 sec)
# INFO:tensorflow:global_step/sec: 178.415
# INFO:tensorflow:loss = 36.131577, step = 9231 (0.559 sec)
# INFO:tensorflow:global_step/sec: 160.171
# INFO:tensorflow:loss = 42.081013, step = 9331 (0.624 sec)
# INFO:tensorflow:global_step/sec: 178.73
# INFO:tensorflow:loss = 48.963287, step = 9431 (0.560 sec)
# INFO:tensorflow:global_step/sec: 160.172
# INFO:tensorflow:loss = 57.235466, step = 9531 (0.630 sec)
# INFO:tensorflow:global_step/sec: 168.234
# INFO:tensorflow:loss = 31.59779, step = 9631 (0.589 sec)
# INFO:tensorflow:global_step/sec: 168.8
# INFO:tensorflow:loss = 32.989166, step = 9731 (0.597 sec)
# INFO:tensorflow:global_step/sec: 170.233
# INFO:tensorflow:loss = 29.48766, step = 9831 (0.581 sec)
# INFO:tensorflow:global_step/sec: 121.389
# INFO:tensorflow:loss = 46.318512, step = 9931 (0.825 sec)
# INFO:tensorflow:global_step/sec: 129.211
# INFO:tensorflow:loss = 31.718788, step = 10031 (0.775 sec)
# INFO:tensorflow:Saving checkpoints for 10130 into C:\Users\Lolly\AppData\Local\Temp\tmpaf205_wz\model.ckpt.
# INFO:tensorflow:Loss for final step: 46.36879.

# %%
results = model.evaluate(input_fn=input_fn(x_test,y_test,num_epochs=1,shuffle=True))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-10-11-14:06:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Lolly\AppData\Local\Temp\tmpaf205_wz\model.ckpt-10130
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-10-11-14:06:16
# INFO:tensorflow:Saving dict for global step 10130: average_loss = 0.73777246, global_step = 10130, label/mean = 1.3333848, loss = 43.528576, prediction/mean = 0.98680574
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10130: C:\Users\Lolly\AppData\Local\Temp\tmpaf205_wz\model.ckpt-10130

# %%
results
# Out:
# {'average_loss': 0.73777246,
#  'global_step': 10130,
#  'label/mean': 1.3333848,
#  'loss': 43.528576,
#  'prediction/mean': 0.98680574}

# %%
for key in sorted(results):
    print("%s %s"%(key,results[key]))
# Out:
# average_loss 0.73777246
# global_step 10130
# label/mean 1.3333848
# loss 43.528576
# prediction/mean 0.98680574

# %%
average_loss = results["average_loss"]

# %%
print("\nRMS error for the test set: ${:.0f}"
        .format(PRICE_SCALING_FACTOR * average_loss**0.5))
# Out:
# RMS error for the test set: $8589

# %%
predict_results = model.predict(input_fn=input_fn(x_predict, y_predict, num_epochs=1, shuffle=False))

# %%
predictions = list(itertools.islice(predict_results, len(x_predict)))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Lolly\AppData\Local\Temp\tmpaf205_wz\model.ckpt-10130
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
predictions
# Out:
# [{'predictions': array([0.21781568], dtype=float32)},
#  {'predictions': array([0.58333236], dtype=float32)},
#  {'predictions': array([0.32442123], dtype=float32)},
#  {'predictions': array([1.6876776], dtype=float32)},
#  {'predictions': array([1.5309374], dtype=float32)},
#  {'predictions': array([0.39242202], dtype=float32)},
#  {'predictions': array([0.44756728], dtype=float32)},
#  {'predictions': array([0.5746234], dtype=float32)},
#  {'predictions': array([0.9235881], dtype=float32)},
#  {'predictions': array([0.5916198], dtype=float32)},
#  {'predictions': array([0.40195495], dtype=float32)},
#  {'predictions': array([-0.10278673], dtype=float32)},
#  {'predictions': array([0.58698684], dtype=float32)},
#  {'predictions': array([-0.15476198], dtype=float32)},
#  {'predictions': array([0.48126632], dtype=float32)},
#  {'predictions': array([1.2170336], dtype=float32)},
#  {'predictions': array([-0.54859895], dtype=float32)},
#  {'predictions': array([0.7744964], dtype=float32)},
#  {'predictions': array([1.5368464], dtype=float32)},
#  {'predictions': array([0.6355422], dtype=float32)},
#  {'predictions': array([0.7663768], dtype=float32)},
#  {'predictions': array([1.0475428], dtype=float32)},
#  {'predictions': array([1.6756022], dtype=float32)},
#  {'predictions': array([1.1453822], dtype=float32)},
#  {'predictions': array([1.7434008], dtype=float32)},
#  {'predictions': array([1.543051], dtype=float32)},
#  {'predictions': array([1.1000826], dtype=float32)},
#  {'predictions': array([0.5955966], dtype=float32)},
#  {'predictions': array([0.15279798], dtype=float32)},
#  {'predictions': array([0.36372024], dtype=float32)},
#  {'predictions': array([0.19866972], dtype=float32)},
#  {'predictions': array([-0.94614], dtype=float32)},
#  {'predictions': array([0.59064513], dtype=float32)},
#  {'predictions': array([2.0890124], dtype=float32)},
#  {'predictions': array([0.40426284], dtype=float32)},
#  {'predictions': array([1.3906825], dtype=float32)},
#  {'predictions': array([-0.24714251], dtype=float32)},
#  {'predictions': array([1.9207537], dtype=float32)},
#  {'predictions': array([0.95597106], dtype=float32)}]

# %%
predicted_prices = [obj['predictions'][0] * PRICE_SCALING_FACTOR for obj in predictions]

# %%
predicted_prices
# Out:
# [2178.1568229198456,
#  5833.32359790802,
#  3244.21226978302,
#  16876.776218414307,
#  15309.374332427979,
#  3924.2202043533325,
#  4475.6728410720825,
#  5746.234059333801,
#  9235.880970954895,
#  5916.197896003723,
#  4019.5494890213013,
#  -1027.8673470020294,
#  5869.8683977127075,
#  -1547.6198494434357,
#  4812.663197517395,
#  12170.336246490479,
#  -5485.989451408386,
#  7744.963765144348,
#  15368.46399307251,
#  6355.422139167786,
#  7663.76793384552,
#  10475.428104400635,
#  16756.021976470947,
#  11453.821659088135,
#  17434.00812149048,
#  15430.5100440979,
#  11000.826358795166,
#  5955.966114997864,
#  1527.9798209667206,
#  3637.2023820877075,
#  1986.6971671581268,
#  -9461.399912834167,
#  5906.451344490051,
#  20890.12384414673,
#  4042.6284074783325,
#  13906.824588775635,
#  -2471.425086259842,
#  19207.537174224854,
#  9559.710621833801]

# %%
compare_df = x_predict.copy()

# %%
compare_df
# Out:
#               make fuel-type aspiration num-of-doors   body-style  \
# 98          nissan       gas        std          two      hardtop
# 141         subaru       gas        std         four        sedan
# 21           dodge       gas        std          two    hatchback
# 72   mercedes-benz       gas        std          two  convertible
# 84      mitsubishi       gas      turbo          two    hatchback
# 151         toyota       gas        std          two    hatchback
# 99          nissan       gas        std         four    hatchback
# 113         peugot       gas        std         four        wagon
# 192     volkswagen    diesel      turbo         four        sedan
# 139         subaru       gas        std          two    hatchback
# 154         toyota       gas        std         four        wagon
# 120       plymouth       gas        std         four    hatchback
# 11             bmw       gas        std         four        sedan
# 199          volvo       gas      turbo         four        wagon
# 80      mitsubishi       gas      turbo          two    hatchback
# 62           mazda       gas        std         four        sedan
# 155         toyota       gas        std         four        wagon
# 108         peugot    diesel      turbo         four        sedan
# 186     volkswagen       gas        std         four        sedan
# 112         peugot    diesel      turbo         four        sedan
# 115         peugot       gas        std         four        sedan
# 188     volkswagen       gas        std         four        sedan
# 194          volvo       gas        std         four        sedan
# 174         toyota    diesel      turbo         four        sedan
# 82      mitsubishi       gas      turbo          two    hatchback
# 14             bmw       gas        std         four        sedan
# 190     volkswagen       gas        std          two    hatchback
# 37           honda       gas        std          two    hatchback
# 78      mitsubishi       gas        std          two    hatchback
# 31           honda       gas        std          two    hatchback
# 35           honda       gas        std         four        sedan
# 58           mazda       gas        std          two    hatchback
# 145         subaru       gas      turbo         four        sedan
# 126        porsche       gas        std          two      hardtop
# 75         mercury       gas      turbo          two    hatchback
# 71   mercedes-benz       gas        std         four        sedan
# 136           saab       gas      turbo          two    hatchback
# 197          volvo       gas        std         four        wagon
# 85      mitsubishi       gas        std         four        sedan
#
#     drive-wheels  curb-weight engine-type num-of-cylinders  engine-size  \
# 98           fwd       2008.0         ohc             four         97.0
# 141          fwd       2145.0        ohcf             four        108.0
# 21           fwd       1876.0         ohc             four         90.0
# 72           rwd       3685.0        ohcv            eight        234.0
# 84           fwd       2926.0         ohc             four        156.0
# 151          fwd       2040.0         ohc             four         92.0
# 99           fwd       2324.0         ohc             four        120.0
# 113          rwd       3285.0           l             four        120.0
# 192          fwd       2579.0         ohc             four         97.0
# 139          fwd       2120.0        ohcf             four        108.0
# 154          4wd       2290.0         ohc             four         92.0
# 120          fwd       1967.0         ohc             four         90.0
# 11           rwd       2395.0         ohc             four        108.0
# 199          rwd       3157.0         ohc             four        130.0
# 80           fwd       2370.0         ohc             four        110.0
# 62           fwd       2410.0         ohc             four        122.0
# 155          4wd       3110.0         ohc             four         92.0
# 108          rwd       3197.0           l             four        152.0
# 186          fwd       2275.0         ohc             four        109.0
# 112          rwd       3252.0           l             four        152.0
# 115          rwd       3075.0           l             four        120.0
# 188          fwd       2300.0         ohc             four        109.0
# 194          rwd       2912.0         ohc             four        141.0
# 174          fwd       2480.0         ohc             four        110.0
# 82           fwd       2833.0         ohc             four        156.0
# 14           rwd       3055.0         ohc              six        164.0
# 190          fwd       2221.0         ohc             four        109.0
# 37           fwd       2236.0         ohc             four        110.0
# 78           fwd       2004.0         ohc             four         92.0
# 31           fwd       1819.0         ohc             four         92.0
# 35           fwd       2010.0         ohc             four         92.0
# 58           rwd       2500.0       rotor              two         80.0
# 145          4wd       2510.0        ohcf             four        108.0
# 126          rwd       2756.0        ohcf              six        194.0
# 75           rwd       2910.0         ohc             four        140.0
# 71           rwd       3740.0        ohcv            eight        234.0
# 136          fwd       2808.0        dohc             four        121.0
# 197          rwd       3042.0         ohc             four        141.0
# 85           fwd       2365.0         ohc             four        122.0
#
#     fuel-system  horsepower  peak-rpm  city-mpg  highway-mpg
# 98         2bbl        69.0    5200.0      31.0         37.0
# 141        2bbl        82.0    4800.0      32.0         37.0
# 21         2bbl        68.0    5500.0      37.0         41.0
# 72         mpfi       155.0    4750.0      16.0         18.0
# 84         spdi       145.0    5000.0      19.0         24.0
# 151        2bbl        62.0    4800.0      31.0         38.0
# 99         2bbl        97.0    5200.0      27.0         34.0
# 113        mpfi        95.0    5000.0      19.0         24.0
# 192         idi        68.0    4500.0      33.0         38.0
# 139        2bbl        73.0    4400.0      26.0         31.0
# 154        2bbl        62.0    4800.0      27.0         32.0
# 120        2bbl        68.0    5500.0      31.0         38.0
# 11         mpfi       101.0    5800.0      23.0         29.0
# 199        mpfi       162.0    5100.0      17.0         22.0
# 80         spdi       116.0    5500.0      23.0         30.0
# 62         2bbl        84.0    4800.0      26.0         32.0
# 155        2bbl        62.0    4800.0      27.0         32.0
# 108         idi        95.0    4150.0      28.0         33.0
# 186        mpfi        85.0    5250.0      27.0         34.0
# 112         idi        95.0    4150.0      28.0         33.0
# 115        mpfi        97.0    5000.0      19.0         24.0
# 188        mpfi       100.0    5500.0      26.0         32.0
# 194        mpfi       114.0    5400.0      23.0         28.0
# 174         idi        73.0    4500.0      30.0         33.0
# 82         spdi       145.0    5000.0      19.0         24.0
# 14         mpfi       121.0    4250.0      20.0         25.0
# 190        mpfi        90.0    5500.0      24.0         29.0
# 37         1bbl        86.0    5800.0      27.0         33.0
# 78         2bbl        68.0    5500.0      31.0         38.0
# 31         1bbl        76.0    6000.0      31.0         38.0
# 35         1bbl        76.0    6000.0      30.0         34.0
# 58         mpfi       135.0    6000.0      16.0         23.0
# 145        mpfi       111.0    4800.0      24.0         29.0
# 126        mpfi       207.0    5900.0      17.0         25.0
# 75         mpfi       175.0    5000.0      19.0         24.0
# 71         mpfi       155.0    4750.0      16.0         18.0
# 136        mpfi       160.0    5500.0      19.0         26.0
# 197        mpfi       114.0    5400.0      24.0         28.0
# 85         2bbl        88.0    5000.0      25.0         32.0

# %%
compare_df['actual-price'] = y_predict
compare_df['predicted-price'] = predicted_prices

# %%
compare_df
# Out:
#               make fuel-type aspiration num-of-doors   body-style  \
# 98          nissan       gas        std          two      hardtop
# 141         subaru       gas        std         four        sedan
# 21           dodge       gas        std          two    hatchback
# 72   mercedes-benz       gas        std          two  convertible
# 84      mitsubishi       gas      turbo          two    hatchback
# 151         toyota       gas        std          two    hatchback
# 99          nissan       gas        std         four    hatchback
# 113         peugot       gas        std         four        wagon
# 192     volkswagen    diesel      turbo         four        sedan
# 139         subaru       gas        std          two    hatchback
# 154         toyota       gas        std         four        wagon
# 120       plymouth       gas        std         four    hatchback
# 11             bmw       gas        std         four        sedan
# 199          volvo       gas      turbo         four        wagon
# 80      mitsubishi       gas      turbo          two    hatchback
# 62           mazda       gas        std         four        sedan
# 155         toyota       gas        std         four        wagon
# 108         peugot    diesel      turbo         four        sedan
# 186     volkswagen       gas        std         four        sedan
# 112         peugot    diesel      turbo         four        sedan
# 115         peugot       gas        std         four        sedan
# 188     volkswagen       gas        std         four        sedan
# 194          volvo       gas        std         four        sedan
# 174         toyota    diesel      turbo         four        sedan
# 82      mitsubishi       gas      turbo          two    hatchback
# 14             bmw       gas        std         four        sedan
# 190     volkswagen       gas        std          two    hatchback
# 37           honda       gas        std          two    hatchback
# 78      mitsubishi       gas        std          two    hatchback
# 31           honda       gas        std          two    hatchback
# 35           honda       gas        std         four        sedan
# 58           mazda       gas        std          two    hatchback
# 145         subaru       gas      turbo         four        sedan
# 126        porsche       gas        std          two      hardtop
# 75         mercury       gas      turbo          two    hatchback
# 71   mercedes-benz       gas        std         four        sedan
# 136           saab       gas      turbo          two    hatchback
# 197          volvo       gas        std         four        wagon
# 85      mitsubishi       gas        std         four        sedan
#
#     drive-wheels  curb-weight engine-type num-of-cylinders  engine-size  \
# 98           fwd       2008.0         ohc             four         97.0
# 141          fwd       2145.0        ohcf             four        108.0
# 21           fwd       1876.0         ohc             four         90.0
# 72           rwd       3685.0        ohcv            eight        234.0
# 84           fwd       2926.0         ohc             four        156.0
# 151          fwd       2040.0         ohc             four         92.0
# 99           fwd       2324.0         ohc             four        120.0
# 113          rwd       3285.0           l             four        120.0
# 192          fwd       2579.0         ohc             four         97.0
# 139          fwd       2120.0        ohcf             four        108.0
# 154          4wd       2290.0         ohc             four         92.0
# 120          fwd       1967.0         ohc             four         90.0
# 11           rwd       2395.0         ohc             four        108.0
# 199          rwd       3157.0         ohc             four        130.0
# 80           fwd       2370.0         ohc             four        110.0
# 62           fwd       2410.0         ohc             four        122.0
# 155          4wd       3110.0         ohc             four         92.0
# 108          rwd       3197.0           l             four        152.0
# 186          fwd       2275.0         ohc             four        109.0
# 112          rwd       3252.0           l             four        152.0
# 115          rwd       3075.0           l             four        120.0
# 188          fwd       2300.0         ohc             four        109.0
# 194          rwd       2912.0         ohc             four        141.0
# 174          fwd       2480.0         ohc             four        110.0
# 82           fwd       2833.0         ohc             four        156.0
# 14           rwd       3055.0         ohc              six        164.0
# 190          fwd       2221.0         ohc             four        109.0
# 37           fwd       2236.0         ohc             four        110.0
# 78           fwd       2004.0         ohc             four         92.0
# 31           fwd       1819.0         ohc             four         92.0
# 35           fwd       2010.0         ohc             four         92.0
# 58           rwd       2500.0       rotor              two         80.0
# 145          4wd       2510.0        ohcf             four        108.0
# 126          rwd       2756.0        ohcf              six        194.0
# 75           rwd       2910.0         ohc             four        140.0
# 71           rwd       3740.0        ohcv            eight        234.0
# 136          fwd       2808.0        dohc             four        121.0
# 197          rwd       3042.0         ohc             four        141.0
# 85           fwd       2365.0         ohc             four        122.0
#
#     fuel-system  horsepower  peak-rpm  city-mpg  highway-mpg  actual-price  \
# 98         2bbl        69.0    5200.0      31.0         37.0        0.8249
# 141        2bbl        82.0    4800.0      32.0         37.0        0.7126
# 21         2bbl        68.0    5500.0      37.0         41.0        0.5572
# 72         mpfi       155.0    4750.0      16.0         18.0        3.5056
# 84         spdi       145.0    5000.0      19.0         24.0        1.4489
# 151        2bbl        62.0    4800.0      31.0         38.0        0.6338
# 99         2bbl        97.0    5200.0      27.0         34.0        0.8949
# 113        mpfi        95.0    5000.0      19.0         24.0        1.6695
# 192         idi        68.0    4500.0      33.0         38.0        1.3845
# 139        2bbl        73.0    4400.0      26.0         31.0        0.7053
# 154        2bbl        62.0    4800.0      27.0         32.0        0.7898
# 120        2bbl        68.0    5500.0      31.0         38.0        0.6229
# 11         mpfi       101.0    5800.0      23.0         29.0        1.6925
# 199        mpfi       162.0    5100.0      17.0         22.0        1.8950
# 80         spdi       116.0    5500.0      23.0         30.0        0.9959
# 62         2bbl        84.0    4800.0      26.0         32.0        1.0245
# 155        2bbl        62.0    4800.0      27.0         32.0        0.8778
# 108         idi        95.0    4150.0      28.0         33.0        1.3200
# 186        mpfi        85.0    5250.0      27.0         34.0        0.8495
# 112         idi        95.0    4150.0      28.0         33.0        1.6900
# 115        mpfi        97.0    5000.0      19.0         24.0        1.6630
# 188        mpfi       100.0    5500.0      26.0         32.0        0.9995
# 194        mpfi       114.0    5400.0      23.0         28.0        1.2940
# 174         idi        73.0    4500.0      30.0         33.0        1.0698
# 82         spdi       145.0    5000.0      19.0         24.0        1.2629
# 14         mpfi       121.0    4250.0      20.0         25.0        2.4565
# 190        mpfi        90.0    5500.0      24.0         29.0        0.9980
# 37         1bbl        86.0    5800.0      27.0         33.0        0.7895
# 78         2bbl        68.0    5500.0      31.0         38.0        0.6669
# 31         1bbl        76.0    6000.0      31.0         38.0        0.6855
# 35         1bbl        76.0    6000.0      30.0         34.0        0.7295
# 58         mpfi       135.0    6000.0      16.0         23.0        1.5645
# 145        mpfi       111.0    4800.0      24.0         29.0        1.1259
# 126        mpfi       207.0    5900.0      17.0         25.0        3.2528
# 75         mpfi       175.0    5000.0      19.0         24.0        1.6503
# 71         mpfi       155.0    4750.0      16.0         18.0        3.4184
# 136        mpfi       160.0    5500.0      19.0         26.0        1.8150
# 197        mpfi       114.0    5400.0      24.0         28.0        1.6515
# 85         2bbl        88.0    5000.0      25.0         32.0        0.6989
#
#      predicted-price
# 98       2178.156823
# 141      5833.323598
# 21       3244.212270
# 72      16876.776218
# 84      15309.374332
# 151      3924.220204
# 99       4475.672841
# 113      5746.234059
# 192      9235.880971
# 139      5916.197896
# 154      4019.549489
# 120     -1027.867347
# 11       5869.868398
# 199     -1547.619849
# 80       4812.663198
# 62      12170.336246
# 155     -5485.989451
# 108      7744.963765
# 186     15368.463993
# 112      6355.422139
# 115      7663.767934
# 188     10475.428104
# 194     16756.021976
# 174     11453.821659
# 82      17434.008121
# 14      15430.510044
# 190     11000.826359
# 37       5955.966115
# 78       1527.979821
# 31       3637.202382
# 35       1986.697167
# 58      -9461.399913
# 145      5906.451344
# 126     20890.123844
# 75       4042.628407
# 71      13906.824589
# 136     -2471.425086
# 197     19207.537174
# 85       9559.710622
